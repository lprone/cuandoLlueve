# %%
import pandas as pd

# %%
datos_junin = pd.read_csv("1758536.csv", parse_dates=['DATE'])

# %%
datos_junin.head(500)
# Out:
#          STATION       NAME  LATITUDE  LONGITUDE  ELEVATION       DATE  PRCP  \
# 0    ARM00087548  JUNIN, AR   -34.546    -60.931       79.9 1967-05-05   NaN
# 1    ARM00087548  JUNIN, AR   -34.546    -60.931       79.9 1967-05-13   NaN
# 2    ARM00087548  JUNIN, AR   -34.546    -60.931       79.9 1967-06-01   5.1
# 3    ARM00087548  JUNIN, AR   -34.546    -60.931       79.9 1967-06-02   2.0
# 4    ARM00087548  JUNIN, AR   -34.546    -60.931       79.9 1967-06-03   0.0
# 5    ARM00087548  JUNIN, AR   -34.546    -60.931       79.9 1967-06-04   NaN
# 6    ARM00087548  JUNIN, AR   -34.546    -60.931       79.9 1967-06-05   NaN
# 7    ARM00087548  JUNIN, AR   -34.546    -60.931       79.9 1967-06-06   NaN
# 8    ARM00087548  JUNIN, AR   -34.546    -60.931       79.9 1967-06-10   NaN
# 9    ARM00087548  JUNIN, AR   -34.546    -60.931       79.9 1967-06-11   NaN
# 10   ARM00087548  JUNIN, AR   -34.546    -60.931       79.9 1967-06-12   NaN
# ...

# %%
data_pergamino = pd.read_excel("NH0145_pergamino.xls")

# %%
data_gral_villegas = pd.read_excel("NH0038_gralVillegas.xls")

# %%
data_pergamino.head(100)
# Out:
#                     Fecha  Temperatura_Abrigo_150cm  \
# 0   1931-01-01 00:00:00.0                       NaN
# 1   1931-01-02 00:00:00.0                     26.60
# 2   1931-01-03 00:00:00.0                     26.65
# 3   1931-01-04 00:00:00.0                     23.50
# 4   1931-01-05 00:00:00.0                     25.10
# 5   1931-01-06 00:00:00.0                     15.05
# 6   1931-01-07 00:00:00.0                     17.85
# 7   1931-01-08 00:00:00.0                     19.95
# 8   1931-01-09 00:00:00.0                     23.20
# 9   1931-01-10 00:00:00.0                     25.35
# 10  1931-01-11 00:00:00.0                     26.40
# 11  1931-01-12 00:00:00.0                     25.60
# 12  1931-01-13 00:00:00.0                     26.65
# 13  1931-01-14 00:00:00.0                       NaN
# 14  1931-01-15 00:00:00.0                       NaN
# 15  1931-01-16 00:00:00.0                       NaN
# 16  1931-01-17 00:00:00.0                       NaN
# ...

# %%
data_gral_villegas.head(100)
# Out:
#                     Fecha  Temperatura_Abrigo_150cm  \
# 0   1973-04-01 00:00:00.0                     15.30
# 1   1973-04-02 00:00:00.0                     15.15
# 2   1973-04-03 00:00:00.0                     18.35
# 3   1973-04-04 00:00:00.0                     16.20
# 4   1973-04-05 00:00:00.0                     15.50
# 5   1973-04-06 00:00:00.0                     18.15
# 6   1973-04-07 00:00:00.0                      9.90
# 7   1973-04-08 00:00:00.0                     15.05
# 8   1973-04-09 00:00:00.0                     18.50
# 9   1973-04-10 00:00:00.0                     18.75
# 10  1973-04-11 00:00:00.0                     16.10
# 11  1973-04-12 00:00:00.0                     15.65
# 12  1973-04-13 00:00:00.0                     15.55
# 13  1973-04-14 00:00:00.0                     16.85
# 14  1973-04-15 00:00:00.0                     12.45
# 15  1973-04-16 00:00:00.0                     12.20
# 16  1973-04-17 00:00:00.0                     16.50
# ...
